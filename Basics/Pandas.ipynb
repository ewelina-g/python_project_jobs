# %%
import pandas as pd

# %%
! pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 12.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df= dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby(['job_title_short','job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg','salary_hour_avg']].agg(['min','max'])
# Out:
#                           salary_year_avg           salary_hour_avg
#                                       min       max             min    max
# job_title_short
# Business Analyst                  16500.0  387460.0          10.835  132.5
# Cloud Engineer                    42000.0  280000.0          18.500   91.0
# Data Analyst                      25000.0  650000.0           8.000  391.0
# Data Engineer                     15000.0  525000.0           8.000  184.5
# Data Scientist                    27000.0  960000.0           8.000  237.5
# Machine Learning Engineer         30000.0  325000.0          10.000   87.5
# Senior Data Analyst               30000.0  425000.0          13.000  130.0
# Senior Data Engineer              35000.0  425000.0          12.500  170.0
# Senior Data Scientist             45000.0  890000.0          17.500  150.0
# Software Engineer                 28000.0  375000.0          11.000  102.5

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Kongo']).any()
# Out:
# np.False_

# %%
pol = df[df.job_country =='Poland']

# %%
pol
# Out:
#                   job_title_short  \
# 18                   Data Analyst
# 108                 Data Engineer
# 125                 Data Engineer
# 136                Data Scientist
# 351             Software Engineer
# ...                           ...
# 785549             Data Scientist
# 785592        Senior Data Analyst
# 785650          Software Engineer
# 785669  Machine Learning Engineer
# 785702           Business Analyst
#
#                                                 job_title     job_location  \
# 18                                           Data Analyst   Warsaw, Poland
# 108                    Chapter Lead Data Engineers Poland  Wrocław, Poland
# 125                                         Data Engineer   Kraków, Poland
# 136                   Mid/ Senior Data Scientist with NLP         Anywhere
# 351                       Data Platform Software Engineer   Warsaw, Poland
# ...                                                   ...              ...
# ...

# %%
df[df.job_country =='Poland']
# Out:
#                   job_title_short  \
# 18                   Data Analyst
# 108                 Data Engineer
# 125                 Data Engineer
# 136                Data Scientist
# 351             Software Engineer
# ...                           ...
# 785549             Data Scientist
# 785592        Senior Data Analyst
# 785650          Software Engineer
# 785669  Machine Learning Engineer
# 785702           Business Analyst
#
#                                                 job_title     job_location  \
# 18                                           Data Analyst   Warsaw, Poland
# 108                    Chapter Lead Data Engineers Poland  Wrocław, Poland
# 125                                         Data Engineer   Kraków, Poland
# 136                   Mid/ Senior Data Scientist with NLP         Anywhere
# 351                       Data Platform Software Engineer   Warsaw, Poland
# ...                                                   ...              ...
# ...

# %%
pol = pol.dropna(subset='salary_year_avg')

# %%
pol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1490 to 783448
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        200 non-null    object
#  1   job_title              200 non-null    object
#  2   job_location           200 non-null    object
#  3   job_via                200 non-null    object
#  4   job_schedule_type      200 non-null    object
#  5   job_work_from_home     200 non-null    bool
#  6   search_location        200 non-null    object
#  7   job_posted_date        200 non-null    datetime64[ns]
#  8   job_no_degree_mention  200 non-null    bool
#  9   job_health_insurance   200 non-null    bool
#  10  job_country            200 non-null    object
#  11  salary_rate            200 non-null    object
#  12  salary_year_avg        200 non-null    float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
pol.groupby('job_title_short')[['salary_year_avg']].agg(['min','max','median','count']).sort_values(('salary_year_avg', 'median'), ascending = False)
# Out:
#                           salary_year_avg
#                                       min       max    median count
# job_title_short
# Senior Data Scientist             88128.0  157500.0  157500.0    12
# Data Engineer                     45000.0  164500.0  133500.0    46
# Data Scientist                    43200.0  186928.0  131867.0    29
# Senior Data Analyst               86400.0  119400.0  111175.0     9
# Machine Learning Engineer         56700.0  186000.0   89100.0    23
# Data Analyst                      43200.0  165000.0   89100.0    43
# Senior Data Engineer              45000.0  147500.0   89100.0     9
# Software Engineer                 65769.0  156500.0   89100.0    15
# Business Analyst                  56700.0  153500.0   87050.0     8
# Cloud Engineer                    56700.0  221000.0   84150.0     6
